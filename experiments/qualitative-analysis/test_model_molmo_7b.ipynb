# %%
import os
import json
import pprint
from gradio_client import Client, handle_file
from dotenv import load_dotenv

load_dotenv()

hf_token = os.getenv("HUGGINGFACE_TOKEN")

# %%
client = Client("akhaliq/Molmo-7B-D-0924", hf_token=hf_token)

def encode_image(image_path):
    return handle_file(image_path)
# Out:
# Loaded as API: https://akhaliq-molmo-7b-d-0924.hf.space ✔

# %% [markdown]
# ##### 1. Image Captioning (Descriptive Ability)

# %%
image_path = 'images/Picture1.jpg'
encoded_image = encode_image(image_path)

text_prompt = "What is the farmer doing in the image?"

result1 = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result1)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.']]

# %%
image_path = 'images/Picture1.jpg'
encoded_image = encode_image(image_path)

text_prompt = "Describe the background of the image in detail."

result2 = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result2)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.']]

# %% [markdown]
# ##### 2. Visual Question Answering (VQA)

# %%
image_path = 'images/Picture2.jpg'
encoded_image = encode_image(image_path)

text_prompt = "What color is the child\'s raincoat?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.']]

# %%
image_path = 'images/Picture2.jpg'
encoded_image = encode_image(image_path)

text_prompt = "Is the child playing alone or is there an animal nearby?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.']]

# %% [markdown]
# ##### 3. Object detection and Recognition

# %%
image_path = 'images\Picture3.jpg'
encoded_image = encode_image(image_path)

text_prompt = "How many distinct objects can you identify on the desk?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.']]

# %%
image_path = 'images\Picture3.jpg'
encoded_image = encode_image(image_path)

text_prompt = "Can you detect any electronic devices in the image?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.'],
#  ['Can you detect any electronic devices in the image?',
#   '<points x1="40.5" y1="44.6" x2="66.0" y2="43.9" alt="electronic '
#   'devices">electronic devices</points>']]

# %% [markdown]
# ##### 4. Scene Understanding & Context Awareness

# %%
image_path = 'images\Picture4.jpg'
encoded_image = encode_image(image_path)

text_prompt = "Should the car stop or continue moving in this image?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.'],
#  ['Can you detect any electronic devices in the image?',
#   '<points x1="40.5" y1="44.6" x2="66.0" y2="43.9" alt="electronic '
#   'devices">electronic devices</points>'],
#  ['Should the car stop or continue moving in this image?',
#   'The car should stop. There are several people crossing the street on a '
#   'zebra crossing, and the traffic light is showing a red signal. According to '
#   'traffic rules, vehicles must stop at red lights and allow pedestrians to '
#   'cross safely. The presence of pedestrians on the crosswalk and the active '
#   'red light clearly indicate that the car should come to a complete stop and '
#   'wait for the signal to change before proceeding.']]

# %%
image_path = 'images\Picture4.jpg'
encoded_image = encode_image(image_path)

text_prompt = "What does the red traffic light indicate for vehicles?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.'],
#  ['Can you detect any electronic devices in the image?',
#   '<points x1="40.5" y1="44.6" x2="66.0" y2="43.9" alt="electronic '
#   'devices">electronic devices</points>'],
#  ['Should the car stop or continue moving in this image?',
#   'The car should stop. There are several people crossing the street on a '
#   'zebra crossing, and the traffic light is showing a red signal. According to '
#   'traffic rules, vehicles must stop at red lights and allow pedestrians to '
#   'cross safely. The presence of pedestrians on the crosswalk and the active '
#   'red light clearly indicate that the car should come to a complete stop and '
#   'wait for the signal to change before proceeding.'],
#  ['What does the red traffic light indicate for vehicles?',
#   'The red traffic light indicates that vehicles should stop and not proceed '
#   'through the intersection. This is a standard traffic signal that all '
#   'drivers must follow to ensure safety and orderly traffic flow at '
#   'intersections.']]

# %% [markdown]
# ##### 5. Text-Image Matching (Multimodal Consistency)

# %%
image_path = 'images\Picture5.jpg'
encoded_image = encode_image(image_path)

text_prompt = "Which caption better describes the image: (A) \"A woman enjoying a peaceful reading session outdoors\" or (B) \"A woman playing soccer in the park\"?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.'],
#  ['Can you detect any electronic devices in the image?',
#   '<points x1="40.5" y1="44.6" x2="66.0" y2="43.9" alt="electronic '
#   'devices">electronic devices</points>'],
#  ['Should the car stop or continue moving in this image?',
#   'The car should stop. There are several people crossing the street on a '
#   'zebra crossing, and the traffic light is showing a red signal. According to '
#   'traffic rules, vehicles must stop at red lights and allow pedestrians to '
#   'cross safely. The presence of pedestrians on the crosswalk and the active '
#   'red light clearly indicate that the car should come to a complete stop and '
#   'wait for the signal to change before proceeding.'],
#  ['What does the red traffic light indicate for vehicles?',
#   'The red traffic light indicates that vehicles should stop and not proceed '
#   'through the intersection. This is a standard traffic signal that all '
#   'drivers must follow to ensure safety and orderly traffic flow at '
#   'intersections.'],
#  ['Which caption better describes the image: (A) "A woman enjoying a peaceful '
#   'reading session outdoors" or (B) "A woman playing soccer in the park"?',
#   'The caption that better describes the image is (A) "A woman enjoying a '
#   'peaceful reading session outdoors". The image clearly shows a woman lying '
#   'on a blanket in a park setting, reading a book. She is surrounded by trees '
#   'and grass, and appears to be relaxing and enjoying her reading time. There '
#   'is no indication of soccer or any other sport being played in the image.']]

# %%
image_path = 'images\Picture5.jpg'
encoded_image = encode_image(image_path)

text_prompt = "What elements in this image indicate that it is a sunny day?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.'],
#  ['Can you detect any electronic devices in the image?',
#   '<points x1="40.5" y1="44.6" x2="66.0" y2="43.9" alt="electronic '
#   'devices">electronic devices</points>'],
#  ['Should the car stop or continue moving in this image?',
#   'The car should stop. There are several people crossing the street on a '
#   'zebra crossing, and the traffic light is showing a red signal. According to '
#   'traffic rules, vehicles must stop at red lights and allow pedestrians to '
#   'cross safely. The presence of pedestrians on the crosswalk and the active '
#   'red light clearly indicate that the car should come to a complete stop and '
#   'wait for the signal to change before proceeding.'],
#  ['What does the red traffic light indicate for vehicles?',
#   'The red traffic light indicates that vehicles should stop and not proceed '
#   'through the intersection. This is a standard traffic signal that all '
#   'drivers must follow to ensure safety and orderly traffic flow at '
#   'intersections.'],
#  ['Which caption better describes the image: (A) "A woman enjoying a peaceful '
#   'reading session outdoors" or (B) "A woman playing soccer in the park"?',
#   'The caption that better describes the image is (A) "A woman enjoying a '
#   'peaceful reading session outdoors". The image clearly shows a woman lying '
#   'on a blanket in a park setting, reading a book. She is surrounded by trees '
#   'and grass, and appears to be relaxing and enjoying her reading time. There '
#   'is no indication of soccer or any other sport being played in the image.'],
#  ['What elements in this image indicate that it is a sunny day?',
#   "Several elements in the image indicate it's a sunny day:\n"
#   '\n'
#   '1. The woman is reading a book outside, suggesting good weather for outdoor '
#   'activities.\n'
#   "2. There's a shadow cast on the grass, which is a clear sign of direct "
#   'sunlight.\n'
#   '3. The trees in the background are well-lit, indicating bright sunlight.\n'
#   '4. The overall lighting in the scene appears bright and natural, typical of '
#   'a sunny day.\n'
#   '5. The woman is wearing a green shirt, which might be chosen for its '
#   'cooling properties on a warm, sunny day.\n'
#   '\n'
#   'These visual cues collectively paint a picture of a pleasant, sunny day '
#   'ideal for relaxing outdoors with a good book.']]

# %% [markdown]
# ##### 6. Optical Character Recognition (OCR) & Text-in-Image Understanding

# %%
image_path = 'images\Picture6.jpg'
encoded_image = encode_image(image_path)

text_prompt = "What is the main headline of the newspaper?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.'],
#  ['Can you detect any electronic devices in the image?',
#   '<points x1="40.5" y1="44.6" x2="66.0" y2="43.9" alt="electronic '
#   'devices">electronic devices</points>'],
#  ['Should the car stop or continue moving in this image?',
#   'The car should stop. There are several people crossing the street on a '
#   'zebra crossing, and the traffic light is showing a red signal. According to '
#   'traffic rules, vehicles must stop at red lights and allow pedestrians to '
#   'cross safely. The presence of pedestrians on the crosswalk and the active '
#   'red light clearly indicate that the car should come to a complete stop and '
#   'wait for the signal to change before proceeding.'],
#  ['What does the red traffic light indicate for vehicles?',
#   'The red traffic light indicates that vehicles should stop and not proceed '
#   'through the intersection. This is a standard traffic signal that all '
#   'drivers must follow to ensure safety and orderly traffic flow at '
#   'intersections.'],
#  ['Which caption better describes the image: (A) "A woman enjoying a peaceful '
#   'reading session outdoors" or (B) "A woman playing soccer in the park"?',
#   'The caption that better describes the image is (A) "A woman enjoying a '
#   'peaceful reading session outdoors". The image clearly shows a woman lying '
#   'on a blanket in a park setting, reading a book. She is surrounded by trees '
#   'and grass, and appears to be relaxing and enjoying her reading time. There '
#   'is no indication of soccer or any other sport being played in the image.'],
#  ['What elements in this image indicate that it is a sunny day?',
#   "Several elements in the image indicate it's a sunny day:\n"
#   '\n'
#   '1. The woman is reading a book outside, suggesting good weather for outdoor '
#   'activities.\n'
#   "2. There's a shadow cast on the grass, which is a clear sign of direct "
#   'sunlight.\n'
#   '3. The trees in the background are well-lit, indicating bright sunlight.\n'
#   '4. The overall lighting in the scene appears bright and natural, typical of '
#   'a sunny day.\n'
#   '5. The woman is wearing a green shirt, which might be chosen for its '
#   'cooling properties on a warm, sunny day.\n'
#   '\n'
#   'These visual cues collectively paint a picture of a pleasant, sunny day '
#   'ideal for relaxing outdoors with a good book.'],
#  ['What is the main headline of the newspaper?',
#   'The main headline of the newspaper is "MEN WALK ON MOON; ASTRONAUTS LAND ON '
#   'PLAIN; COLLECT ROCKS, PLANT FLAG".']]

# %%
image_path = 'images\Picture6.jpg'
encoded_image = encode_image(image_path)

text_prompt = "Does the text suggest a historical or fictional event?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.'],
#  ['Can you detect any electronic devices in the image?',
#   '<points x1="40.5" y1="44.6" x2="66.0" y2="43.9" alt="electronic '
#   'devices">electronic devices</points>'],
#  ['Should the car stop or continue moving in this image?',
#   'The car should stop. There are several people crossing the street on a '
#   'zebra crossing, and the traffic light is showing a red signal. According to '
#   'traffic rules, vehicles must stop at red lights and allow pedestrians to '
#   'cross safely. The presence of pedestrians on the crosswalk and the active '
#   'red light clearly indicate that the car should come to a complete stop and '
#   'wait for the signal to change before proceeding.'],
#  ['What does the red traffic light indicate for vehicles?',
#   'The red traffic light indicates that vehicles should stop and not proceed '
#   'through the intersection. This is a standard traffic signal that all '
#   'drivers must follow to ensure safety and orderly traffic flow at '
#   'intersections.'],
#  ['Which caption better describes the image: (A) "A woman enjoying a peaceful '
#   'reading session outdoors" or (B) "A woman playing soccer in the park"?',
#   'The caption that better describes the image is (A) "A woman enjoying a '
#   'peaceful reading session outdoors". The image clearly shows a woman lying '
#   'on a blanket in a park setting, reading a book. She is surrounded by trees '
#   'and grass, and appears to be relaxing and enjoying her reading time. There '
#   'is no indication of soccer or any other sport being played in the image.'],
#  ['What elements in this image indicate that it is a sunny day?',
#   "Several elements in the image indicate it's a sunny day:\n"
#   '\n'
#   '1. The woman is reading a book outside, suggesting good weather for outdoor '
#   'activities.\n'
#   "2. There's a shadow cast on the grass, which is a clear sign of direct "
#   'sunlight.\n'
#   '3. The trees in the background are well-lit, indicating bright sunlight.\n'
#   '4. The overall lighting in the scene appears bright and natural, typical of '
#   'a sunny day.\n'
#   '5. The woman is wearing a green shirt, which might be chosen for its '
#   'cooling properties on a warm, sunny day.\n'
#   '\n'
#   'These visual cues collectively paint a picture of a pleasant, sunny day '
#   'ideal for relaxing outdoors with a good book.'],
#  ['What is the main headline of the newspaper?',
#   'The main headline of the newspaper is "MEN WALK ON MOON; ASTRONAUTS LAND ON '
#   'PLAIN; COLLECT ROCKS, PLANT FLAG".'],
#  ['Does the text suggest a historical or fictional event?',
#   'The text on the newspaper page suggests a historical event. The headline '
#   'reads "MEN WALK ON MOON; ASTRONAUTS LAND ON PLAIN; COLLECT ROCKS, PLANT '
#   'FLAG." This is accompanied by a subheading that states "VOICE FROM MOON: '
#   '\'EAGLE HAS LANDED.\'" These phrases clearly refer to the historic Apollo '
#   '11 moon landing, which occurred on July 20, 1969. The presence of this '
#   "newspaper clipping, along with the man's vintage hairstyle and clothing, "
#   'further reinforces the historical nature of the event being depicted.']]

# %% [markdown]
# ##### 7. Commonsense & Logical Reasoning

# %%
image_path = 'images/Picture7.jpg'
encoded_image = encode_image(image_path)

text_prompt = "Is it normal for a dog to wear glasses and read a newspaper? Why or why not?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.'],
#  ['Can you detect any electronic devices in the image?',
#   '<points x1="40.5" y1="44.6" x2="66.0" y2="43.9" alt="electronic '
#   'devices">electronic devices</points>'],
#  ['Should the car stop or continue moving in this image?',
#   'The car should stop. There are several people crossing the street on a '
#   'zebra crossing, and the traffic light is showing a red signal. According to '
#   'traffic rules, vehicles must stop at red lights and allow pedestrians to '
#   'cross safely. The presence of pedestrians on the crosswalk and the active '
#   'red light clearly indicate that the car should come to a complete stop and '
#   'wait for the signal to change before proceeding.'],
#  ['What does the red traffic light indicate for vehicles?',
#   'The red traffic light indicates that vehicles should stop and not proceed '
#   'through the intersection. This is a standard traffic signal that all '
#   'drivers must follow to ensure safety and orderly traffic flow at '
#   'intersections.'],
#  ['Which caption better describes the image: (A) "A woman enjoying a peaceful '
#   'reading session outdoors" or (B) "A woman playing soccer in the park"?',
#   'The caption that better describes the image is (A) "A woman enjoying a '
#   'peaceful reading session outdoors". The image clearly shows a woman lying '
#   'on a blanket in a park setting, reading a book. She is surrounded by trees '
#   'and grass, and appears to be relaxing and enjoying her reading time. There '
#   'is no indication of soccer or any other sport being played in the image.'],
#  ['What elements in this image indicate that it is a sunny day?',
#   "Several elements in the image indicate it's a sunny day:\n"
#   '\n'
#   '1. The woman is reading a book outside, suggesting good weather for outdoor '
#   'activities.\n'
#   "2. There's a shadow cast on the grass, which is a clear sign of direct "
#   'sunlight.\n'
#   '3. The trees in the background are well-lit, indicating bright sunlight.\n'
#   '4. The overall lighting in the scene appears bright and natural, typical of '
#   'a sunny day.\n'
#   '5. The woman is wearing a green shirt, which might be chosen for its '
#   'cooling properties on a warm, sunny day.\n'
#   '\n'
#   'These visual cues collectively paint a picture of a pleasant, sunny day '
#   'ideal for relaxing outdoors with a good book.'],
#  ['What is the main headline of the newspaper?',
#   'The main headline of the newspaper is "MEN WALK ON MOON; ASTRONAUTS LAND ON '
#   'PLAIN; COLLECT ROCKS, PLANT FLAG".'],
#  ['Does the text suggest a historical or fictional event?',
#   'The text on the newspaper page suggests a historical event. The headline '
#   'reads "MEN WALK ON MOON; ASTRONAUTS LAND ON PLAIN; COLLECT ROCKS, PLANT '
#   'FLAG." This is accompanied by a subheading that states "VOICE FROM MOON: '
#   '\'EAGLE HAS LANDED.\'" These phrases clearly refer to the historic Apollo '
#   '11 moon landing, which occurred on July 20, 1969. The presence of this '
#   "newspaper clipping, along with the man's vintage hairstyle and clothing, "
#   'further reinforces the historical nature of the event being depicted.'],
#  ['Is it normal for a dog to wear glasses and read a newspaper? Why or why '
#   'not?',
#   "No, it's not normal for a dog to wear glasses and read a newspaper. This "
#   "image appears to be digitally altered or AI-generated. Dogs don't naturally "
#   'wear glasses or read newspapers, so this scene is likely created for '
#   'entertainment or artistic purposes. The combination of a dog with reading '
#   'glasses and a cat reading a newspaper is a humorous and unusual scenario '
#   "that wouldn't occur in reality. It's a playful representation of human "
#   'activities that has been given to animals for comedic effect.']]

# %%
image_path = 'images/Picture7.jpg'
encoded_image = encode_image(image_path)

text_prompt = "What is unusual about this scene?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is the farmer doing in the image?',
#   'The farmer in the image is harvesting wheat using a New Holland tractor. '
#   "He's driving the orange tractor through a vast wheat field, actively "
#   'engaged in the process of cutting and gathering the wheat stalks. The '
#   'tractor is equipped with a hay rake, which is visible at the front, helping '
#   'to gather the cut wheat into neat rows behind the vehicle. This method of '
#   'harvesting is known as raking, where the cut wheat is collected and '
#   'gathered into rows, making it easier to gather later. The farmer appears '
#   'focused on his work, maneuvering the tractor through the field to '
#   'efficiently harvest the crop.'],
#  ['Describe the background of the image in detail.',
#   'The background of the image showcases a serene rural landscape. A line of '
#   'trees stretches across the horizon, creating a natural border between the '
#   'sky and the field. The trees appear to be a mix of deciduous and evergreen '
#   'varieties, adding depth and texture to the scene.\n'
#   '\n'
#   'The sky above is a light blue, suggesting a clear, sunny day. The overall '
#   'atmosphere is warm and inviting, typical of a pleasant summer afternoon in '
#   'the countryside.\n'
#   '\n'
#   'This backdrop provides a perfect contrast to the foreground elements, such '
#   'as the wheat field and the tractor, enhancing the overall composition of '
#   'the image and emphasizing the agricultural theme.'],
#  ["What color is the child's raincoat?",
#   'The child in the image is wearing a yellow raincoat.'],
#  ['Is the child playing alone or is there an animal nearby?',
#   'The child is not playing alone. There are two small dogs nearby, both '
#   'wearing raincoats. One dog is wearing an orange raincoat and is looking up '
#   'at the child, while the other dog is wearing a black raincoat and is '
#   'looking at the first dog. The child and the dogs appear to be interacting '
#   'in what looks like a park setting.'],
#  ['How many distinct objects can you identify on the desk?',
#   'In this workspace scene, I can identify several distinct objects:\n'
#   '\n'
#   '1. Two laptops\n'
#   '2. A Starbucks coffee cup\n'
#   '3. A potted plant\n'
#   '4. A spiral-bound calendar\n'
#   '5. A wooden table\n'
#   '6. Two windows\n'
#   '7. Two window shades\n'
#   "8. A person's hand (with a tattoo)\n"
#   '\n'
#   'In total, there are 8 distinct objects visible in the image. The workspace '
#   'appears to be well-organized, with the person actively using one laptop '
#   'while the other is also in use. The presence of the calendar suggests this '
#   'might be a productive work or study area.'],
#  ['Can you detect any electronic devices in the image?',
#   '<points x1="40.5" y1="44.6" x2="66.0" y2="43.9" alt="electronic '
#   'devices">electronic devices</points>'],
#  ['Should the car stop or continue moving in this image?',
#   'The car should stop. There are several people crossing the street on a '
#   'zebra crossing, and the traffic light is showing a red signal. According to '
#   'traffic rules, vehicles must stop at red lights and allow pedestrians to '
#   'cross safely. The presence of pedestrians on the crosswalk and the active '
#   'red light clearly indicate that the car should come to a complete stop and '
#   'wait for the signal to change before proceeding.'],
#  ['What does the red traffic light indicate for vehicles?',
#   'The red traffic light indicates that vehicles should stop and not proceed '
#   'through the intersection. This is a standard traffic signal that all '
#   'drivers must follow to ensure safety and orderly traffic flow at '
#   'intersections.'],
#  ['Which caption better describes the image: (A) "A woman enjoying a peaceful '
#   'reading session outdoors" or (B) "A woman playing soccer in the park"?',
#   'The caption that better describes the image is (A) "A woman enjoying a '
#   'peaceful reading session outdoors". The image clearly shows a woman lying '
#   'on a blanket in a park setting, reading a book. She is surrounded by trees '
#   'and grass, and appears to be relaxing and enjoying her reading time. There '
#   'is no indication of soccer or any other sport being played in the image.'],
#  ['What elements in this image indicate that it is a sunny day?',
#   "Several elements in the image indicate it's a sunny day:\n"
#   '\n'
#   '1. The woman is reading a book outside, suggesting good weather for outdoor '
#   'activities.\n'
#   "2. There's a shadow cast on the grass, which is a clear sign of direct "
#   'sunlight.\n'
#   '3. The trees in the background are well-lit, indicating bright sunlight.\n'
#   '4. The overall lighting in the scene appears bright and natural, typical of '
#   'a sunny day.\n'
#   '5. The woman is wearing a green shirt, which might be chosen for its '
#   'cooling properties on a warm, sunny day.\n'
#   '\n'
#   'These visual cues collectively paint a picture of a pleasant, sunny day '
#   'ideal for relaxing outdoors with a good book.'],
#  ['What is the main headline of the newspaper?',
#   'The main headline of the newspaper is "MEN WALK ON MOON; ASTRONAUTS LAND ON '
#   'PLAIN; COLLECT ROCKS, PLANT FLAG".'],
#  ['Does the text suggest a historical or fictional event?',
#   'The text on the newspaper page suggests a historical event. The headline '
#   'reads "MEN WALK ON MOON; ASTRONAUTS LAND ON PLAIN; COLLECT ROCKS, PLANT '
#   'FLAG." This is accompanied by a subheading that states "VOICE FROM MOON: '
#   '\'EAGLE HAS LANDED.\'" These phrases clearly refer to the historic Apollo '
#   '11 moon landing, which occurred on July 20, 1969. The presence of this '
#   "newspaper clipping, along with the man's vintage hairstyle and clothing, "
#   'further reinforces the historical nature of the event being depicted.'],
#  ['Is it normal for a dog to wear glasses and read a newspaper? Why or why '
#   'not?',
#   "No, it's not normal for a dog to wear glasses and read a newspaper. This "
#   "image appears to be digitally altered or AI-generated. Dogs don't naturally "
#   'wear glasses or read newspapers, so this scene is likely created for '
#   'entertainment or artistic purposes. The combination of a dog with reading '
#   'glasses and a cat reading a newspaper is a humorous and unusual scenario '
#   "that wouldn't occur in reality. It's a playful representation of human "
#   'activities that has been given to animals for comedic effect.'],
#  ['What is unusual about this scene?',
#   "The most unusual aspect of this scene is the dog wearing glasses. It's "
#   'quite uncommon to see a dog, especially one that appears to be a golden '
#   'retriever with a white face, sporting a pair of glasses. This '
#   'anthropomorphic touch adds a whimsical and charming element to the image, '
#   'creating an amusing contrast between the natural appearance of the dog and '
#   "the human accessory it's wearing."]]

# %% [markdown]
# ##### 8. Zero-Shot & Few-Shot Learning

# %%
hf_token2 = os.getenv("HUGGINGFACE_TOKEN2")
client = Client("akhaliq/Molmo-7B-D-0924", hf_token=hf_token2)
# Out:
# Loaded as API: https://akhaliq-molmo-7b-d-0924.hf.space ✔

# %%
image_path = 'images/Picture8.jpg'
encoded_image = encode_image(image_path)

text_prompt = "What is this object, and how does it differ from a real cat?"

result = client.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['What is this object, and how does it differ from a real cat?',
#   'This object is a robotic cat, which differs from a real cat in several '
#   'ways:\n'
#   '\n'
#   '1. It has a metallic body with visible gears and mechanical parts, '
#   'including a gear on its chest.\n'
#   '2. The cat has four mechanical legs instead of the normal four legs of a '
#   'real cat.\n'
#   "3. It has a tail made of metal, unlike a real cat's fur-covered tail.\n"
#   "4. The cat's body is covered in metal armor, giving it a futuristic or "
#   'steampunk appearance.\n'
#   '5. It has a mechanical device on its back, which could be a weapon or some '
#   'kind of backpack.\n'
#   "6. The cat's face is more stylized and cartoon-like compared to a real "
#   "cat's more realistic features.\n"
#   '\n'
#   'While it maintains the general shape and some features of a cat, such as '
#   'its head, ears, and overall form, the robotic cat is clearly an artificial '
#   'creation with mechanical and metallic components that give it a distinct, '
#   'futuristic appearance.']]

# %%
hf_token3 = os.getenv("HUGGINGFACE_TOKEN3")
client3 = Client("akhaliq/Molmo-7B-D-0924", hf_token=hf_token3)
# Out:
# Loaded as API: https://akhaliq-molmo-7b-d-0924.hf.space ✔

# %%
image_path = 'images/Picture8.jpg'
encoded_image = encode_image(image_path)

text_prompt = "Based on the image, can you guess the possible functions of this robotic cat?"

result = client3.predict(
    image=encoded_image,
    text=text_prompt,
    api_name="/chatbot"
)

pprint.pprint(result)
# Out:
# [['Based on the image, can you guess the possible functions of this robotic '
#   'cat?',
#   "While it's difficult to determine the exact functions without more "
#   'information, we can speculate based on the image. This robotic cat appears '
#   'to be designed for a combination of surveillance and assistance roles. The '
#   'camera on its back suggests it could be used for monitoring its '
#   'surroundings or transmitting visual data. The mechanical arms might allow '
#   'it to manipulate objects or provide support to humans. The overall design, '
#   'blending organic and technological elements, indicates it could be a '
#   'prototype for a companion robot that can assist with daily tasks while also '
#   'gathering information about its environment. The cat-like appearance might '
#   'also serve to make it more approachable and less intimidating in human '
#   'interactions.']]
